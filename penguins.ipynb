# %%
import pandas as pd

titan=pd.read_csv("https://raw.githubusercontent.com/Mrt3206/Statistic-Homework/main/penguins2.csv")
print(len(titan))
print(len(titan.columns))
list(titan.columns)
#titan.rename(columns={'Sample Number':'SampleNumber','Individual ID':'IndividualID','Clutch Completion':'ClutchCompletion','Date Egg':'DateEgg',
#                      'Culmen Length (mm)':'CulmenLength(mm)','Flipper Length (mm)':'FlipperLength_mm','Body Mass (g)':'BodyMass_g'}, inplace=True)
#titan.head()
# Out:
# 344
# 7
# ['species',
#  'island',
#  'bill_length_mm',
#  'bill_depth_mm',
#  'flipper_length_mm',
#  'body_mass_g',
#  'sex']

# %%
"""344 rows x 7 columns"""

# %%
import matplotlib.pyplot as plt
import seaborn as sns

f,ax=plt.subplots(figsize = (6,6))
sns.set(style="white")
sns.heatmap(titan.corr(), annot=True, linewidths=0.5, fmt=".1f", ax=ax)
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.title("Correlation Map")
plt.show()

# %%
"""the highest correlation in Penguins data body_mass_g and Flipper Length 0.9"""

# %%
sns.scatterplot(x="body_mass_g",y="flipper_length_mm",data=titan)
#sns.jointplot(data.radius_mean,data.fractal_dimension_mean,kind="regg")
plt.show()

# %%
from scipy import stats

print(titan.bill_length_mm.describe())
print(stats.mode(titan.bill_length_mm))
# Out:
# count    342.000000
# mean      43.921930
# std        5.459584
# min       32.100000
# 25%       39.225000
# 50%       44.450000
# 75%       48.500000
# max       59.600000
# Name: bill_length_mm, dtype: float64
# ModeResult(mode=array([41.1]), count=array([7]))

# %%
"""a) mean					    43.921930
b) minimum, maximum     32.100000, 59.600000
c) mode					41.1
d) median				44.450000"""

# %%
import numpy as np

np.std(titan)
# Out:
# c:\Users\murat\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3613: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# bill_length_mm         5.451596
# bill_depth_mm          1.971904
# flipper_length_mm     14.041141
# body_mass_g          800.781229
# dtype: float64

# %%
sns.set_theme(style="whitegrid")
ay=sns.boxplot(y=titan["bill_length_mm"])

# %%
import numpy as np
sns.set(style="ticks",color_codes=True)
print(np.std(titan))

sns.lineplot(data=np.std(titan))
"""body_mass_g value is less trustable"""
# Out:
# bill_length_mm         5.451596
# bill_depth_mm          1.971904
# flipper_length_mm     14.041141
# body_mass_g          800.781229
# dtype: float64
# c:\Users\murat\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3613: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# 'body_mass_g value is less trustable'
